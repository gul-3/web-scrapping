# %%
import requests
from bs4 import BeautifulSoup
import json
import time
import logging

def scrape_courses(file_name):
    """
    Scrapes course information from a university website based on department links in a JSON file.
    
    Args:
        file_name (str): Name of the JSON file (without extension) containing department links
        
    Returns:
        dict: Dictionary containing all scraped course data
        
    The function also writes the results to a JSON file named '{file_name}_results.json'
    """
    # Set up logging
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s',
        handlers=[
            logging.StreamHandler()
        ]
    )
    
    start_time = time.time()
    logging.info(f"Starting scraping process using links from {file_name}.json")
    
    # Load department links from JSON file
    try:
        with open(f'{file_name}.json', 'r', encoding='utf-8') as f:
            links = json.load(f)
        logging.info(f"Successfully loaded {len(links)} departments from {file_name}.json")
    except FileNotFoundError:
        logging.error(f"File {file_name}.json not found")
        return None
    except json.JSONDecodeError:
        logging.error(f"Invalid JSON format in {file_name}.json")
        return None
    
    # Print links for verification
    logging.info(f"Department links: {links}")
    
    base_url = "https://ects.bilgi.edu.tr"
    
    # Department URLs from the loaded JSON
    departments = links
    
    all_data = {}
    total_courses = 0
    processed_courses = 0
    
    # First pass to count total courses for estimation
    for dept_name, curriculum_url in departments.items():
        try:
            response = requests.get(curriculum_url)
            soup = BeautifulSoup(response.text, 'html.parser')
            
            course_links = soup.find_all('a', href=True)
            dept_courses = sum(1 for link in course_links if '/Course/Detail?catalog_courseId=' in link['href'])
            total_courses += dept_courses
            
            logging.info(f"Department '{dept_name}' has {dept_courses} courses")
        except Exception as e:
            logging.error(f"Error counting courses for department '{dept_name}': {str(e)}")
    
    logging.info(f"Total courses to process: {total_courses}")
    
    # Estimate processing time (assuming ~3 seconds per course)
    seconds_per_course = 3
    estimated_total_seconds = total_courses * seconds_per_course
    estimated_hours = estimated_total_seconds // 3600
    estimated_minutes = (estimated_total_seconds % 3600) // 60
    estimated_seconds = estimated_total_seconds % 60
    
    logging.info(f"Estimated completion time: {estimated_hours}h {estimated_minutes}m {estimated_seconds}s")
    
    # Second pass to actually scrape the data
    for dept_name, curriculum_url in departments.items():
        dept_start_time = time.time()
        logging.info(f"Processing department: '{dept_name}' - URL: {curriculum_url}")
        
        try:
            response = requests.get(curriculum_url)
            soup = BeautifulSoup(response.text, 'html.parser')
            
            courses = []
            
            course_links = soup.find_all('a', href=True)
            dept_course_count = 0
            
            for course in course_links:
                if '/Course/Detail?catalog_courseId=' in course['href']:
                    course_name = course.text.strip()
                    course_link = base_url + course['href']
                    
                    logging.info(f"Processing course: '{course_name}' - {processed_courses+1}/{total_courses}")
                    course_start_time = time.time()
                    
                    # Get each course's detail page
                    try:
                        course_response = requests.get(course_link)
                        course_soup = BeautifulSoup(course_response.text, 'html.parser')
                        
                        course_details = course_soup.find_all('tr')
                        course_description = ""
                        course_learning_outcomes = []
                        
                        for row in course_details:
                            cols = row.find_all('td')
                            if len(cols) >= 2:
                                title = cols[0].text.strip()
                                content = cols[1]
                                
                                if title == "Course Description":
                                    course_description = content.text.strip()
                                
                                elif "Learning Outcomes of the Course Unit" in title:
                                    course_learning_outcomes = [li.text.strip() for li in content.find_all('li')]
                        
                        # Save each course's data
                        if dept_name not in all_data:
                            all_data[dept_name] = []
                        
                        all_data[dept_name].append({
                            "course_name": course_name,
                            "course_link": course_link,
                            "course_description": course_description,
                            "course_learning_outcomes": course_learning_outcomes
                        })
                        
                        dept_course_count += 1
                        processed_courses += 1
                        
                        course_end_time = time.time()
                        course_duration = course_end_time - course_start_time
                        
                        # Update time estimation based on actual performance
                        if processed_courses > 5:  # After processing a few courses to get a better average
                            seconds_per_course = (course_end_time - start_time) / processed_courses
                            remaining_courses = total_courses - processed_courses
                            remaining_seconds = remaining_courses * seconds_per_course
                            
                            remaining_hours = int(remaining_seconds // 3600)
                            remaining_minutes = int((remaining_seconds % 3600) // 60)
                            remaining_seconds = int(remaining_seconds % 60)
                            
                            elapsed = course_end_time - start_time
                            elapsed_hours = int(elapsed // 3600)
                            elapsed_minutes = int((elapsed % 3600) // 60)
                            elapsed_seconds = int(elapsed % 60)
                            
                            logging.info(f"Course processed in {course_duration:.2f}s - " +
                                        f"Progress: {processed_courses}/{total_courses} " +
                                        f"({(processed_courses/total_courses*100):.1f}%) - " +
                                        f"Elapsed: {elapsed_hours}h {elapsed_minutes}m {elapsed_seconds}s - " +
                                        f"ETA: {remaining_hours}h {remaining_minutes}m {remaining_seconds}s")
                        
                    except Exception as e:
                        logging.error(f"Error processing course '{course_name}': {str(e)}")
            
            dept_end_time = time.time()
            dept_duration = dept_end_time - dept_start_time
            logging.info(f"Department '{dept_name}' completed - {dept_course_count} courses processed in {dept_duration:.2f}s")
            
        except Exception as e:
            logging.error(f"Error processing department '{dept_name}': {str(e)}")
    
    # Write all data to JSON file
    output_file = f"{file_name}_results.json"
    try:
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(all_data, f, ensure_ascii=False, indent=4)
        logging.info(f"Done! All data saved to '{output_file}'")
    except Exception as e:
        logging.error(f"Error writing to output file: {str(e)}")
    
    end_time = time.time()
    total_duration = end_time - start_time
    hours = int(total_duration // 3600)
    minutes = int((total_duration % 3600) // 60)
    seconds = int(total_duration % 60)
    
    logging.info(f"Scraping completed in {hours}h {minutes}m {seconds}s")
    logging.info(f"Processed {processed_courses} courses from {len(departments)} departments")
    
    return all_data

# Example usage
if __name__ == "__main__":
    # To use the function, call it with the JSON filename (without extension)
    # For example, if your file is "links.json":
    scrape_courses("")
# Out:
# 2025-03-11 23:33:40,260 - INFO - Starting scraping process using links from linkler_v2.json
# 2025-03-11 23:33:40,263 - INFO - Successfully loaded 2 departments from linkler_v2.json
# 2025-03-11 23:33:40,265 - INFO - Department links: {'International Finance': 'https://ects.bilgi.edu.tr/Department/Curriculum?catalog_departmentId=214496', 'International Trade and Business': 'https://ects.bilgi.edu.tr/Department/Curriculum?catalog_departmentId=214500'}
# 2025-03-11 23:33:40,511 - INFO - Department 'International Finance' has 37 courses
# 2025-03-11 23:33:40,746 - INFO - Department 'International Trade and Business' has 38 courses
# 2025-03-11 23:33:40,747 - INFO - Total courses to process: 75
# 2025-03-11 23:33:40,749 - INFO - Estimated completion time: 0h 3m 45s
# 2025-03-11 23:33:40,751 - INFO - Processing department: 'International Finance' - URL: https://ects.bilgi.edu.tr/Department/Curriculum?catalog_departmentId=214496
# 2025-03-11 23:33:40,991 - INFO - Processing course: 'BUS 120' - 1/75
# 2025-03-11 23:33:42,727 - INFO - Processing course: 'BUS 179' - 2/75
# 2025-03-11 23:33:44,606 - INFO - Processing course: 'EC 101' - 3/75
# 2025-03-11 23:33:46,524 - INFO - Processing course: 'BUS/E 179' - 4/75
# 2025-03-11 23:33:48,430 - INFO - Processing course: 'MATH 175' - 5/75
# 2025-03-11 23:33:50,301 - INFO - Processing course: 'TK 103' - 6/75
# 2025-03-11 23:33:52,175 - INFO - Course processed in 1.87s - Progress: 6/75 (8.0%) - Elapsed: 0h 0m 11s - ETA: 0h 2m 17s
# 2025-03-11 23:33:52,177 - INFO - Processing course: 'BUS 180' - 7/75
# 2025-03-11 23:33:53,968 - INFO - Course processed in 1.79s - Progress: 7/75 (9.3%) - Elapsed: 0h 0m 13s - ETA: 0h 2m 13s
# 2025-03-11 23:33:53,971 - INFO - Processing course: 'EC 102' - 8/75
# 2025-03-11 23:33:55,818 - INFO - Course processed in 1.85s - Progress: 8/75 (10.7%) - Elapsed: 0h 0m 15s - ETA: 0h 2m 10s
# 2025-03-11 23:33:55,820 - INFO - Processing course: 'BUS/E 180' - 9/75
# 2025-03-11 23:33:57,778 - INFO - Course processed in 1.96s - Progress: 9/75 (12.0%) - Elapsed: 0h 0m 17s - ETA: 0h 2m 8s
# 2025-03-11 23:33:57,780 - INFO - Processing course: 'MATH 176' - 10/75
# 2025-03-11 23:33:59,583 - INFO - Course processed in 1.80s - Progress: 10/75 (13.3%) - Elapsed: 0h 0m 19s - ETA: 0h 2m 5s
# 2025-03-11 23:33:59,584 - INFO - Processing course: 'TK 104' - 11/75
# 2025-03-11 23:34:01,497 - INFO - Course processed in 1.91s - Progress: 11/75 (14.7%) - Elapsed: 0h 0m 21s - ETA: 0h 2m 3s
# 2025-03-11 23:34:01,499 - INFO - Processing course: 'BUS 211' - 12/75
# 2025-03-11 23:34:03,462 - INFO - Course processed in 1.96s - Progress: 12/75 (16.0%) - Elapsed: 0h 0m 23s - ETA: 0h 2m 1s
# 2025-03-11 23:34:03,463 - INFO - Processing course: 'BUS 273' - 13/75
# 2025-03-11 23:34:05,306 - INFO - Course processed in 1.84s - Progress: 13/75 (17.3%) - Elapsed: 0h 0m 25s - ETA: 0h 1m 59s
# 2025-03-11 23:34:05,308 - INFO - Processing course: 'MATH 235' - 14/75
# 2025-03-11 23:34:07,089 - INFO - Course processed in 1.78s - Progress: 14/75 (18.7%) - Elapsed: 0h 0m 26s - ETA: 0h 1m 56s
# 2025-03-11 23:34:07,092 - INFO - Processing course: 'HTR 111' - 15/75
# 2025-03-11 23:34:09,062 - INFO - Course processed in 1.97s - Progress: 15/75 (20.0%) - Elapsed: 0h 0m 28s - ETA: 0h 1m 55s
# 2025-03-11 23:34:09,064 - INFO - Processing course: 'BUS 212' - 16/75
# 2025-03-11 23:34:10,882 - INFO - Course processed in 1.82s - Progress: 16/75 (21.3%) - Elapsed: 0h 0m 30s - ETA: 0h 1m 52s
# 2025-03-11 23:34:10,883 - INFO - Processing course: 'BUS 274' - 17/75
# 2025-03-11 23:34:12,676 - INFO - Course processed in 1.79s - Progress: 17/75 (22.7%) - Elapsed: 0h 0m 32s - ETA: 0h 1m 50s
# 2025-03-11 23:34:12,678 - INFO - Processing course: 'HTR 112' - 18/75
# 2025-03-11 23:34:14,576 - INFO - Course processed in 1.89s - Progress: 18/75 (24.0%) - Elapsed: 0h 0m 34s - ETA: 0h 1m 48s
# 2025-03-11 23:34:14,577 - INFO - Processing course: 'INF 301' - 19/75
# 2025-03-11 23:34:16,310 - INFO - Course processed in 1.73s - Progress: 19/75 (25.3%) - Elapsed: 0h 0m 36s - ETA: 0h 1m 46s
# 2025-03-11 23:34:16,312 - INFO - Processing course: 'INF 311' - 20/75
# 2025-03-11 23:34:18,055 - INFO - Course processed in 1.74s - Progress: 20/75 (26.7%) - Elapsed: 0h 0m 37s - ETA: 0h 1m 43s
# 2025-03-11 23:34:18,057 - INFO - Processing course: 'BUS 341' - 21/75
# 2025-03-11 23:34:19,831 - INFO - Course processed in 1.77s - Progress: 21/75 (28.0%) - Elapsed: 0h 0m 39s - ETA: 0h 1m 41s
# 2025-03-11 23:34:19,833 - INFO - Processing course: 'EC 361' - 22/75
# 2025-03-11 23:34:21,605 - INFO - Course processed in 1.77s - Progress: 22/75 (29.3%) - Elapsed: 0h 0m 41s - ETA: 0h 1m 39s
# 2025-03-11 23:34:21,607 - INFO - Processing course: 'INF 302' - 23/75
# 2025-03-11 23:34:23,284 - INFO - Course processed in 1.68s - Progress: 23/75 (30.7%) - Elapsed: 0h 0m 43s - ETA: 0h 1m 37s
# 2025-03-11 23:34:23,285 - INFO - Processing course: 'BUS 352' - 24/75
# 2025-03-11 23:34:25,017 - INFO - Course processed in 1.73s - Progress: 24/75 (32.0%) - Elapsed: 0h 0m 44s - ETA: 0h 1m 35s
# 2025-03-11 23:34:25,019 - INFO - Processing course: 'LAW 429' - 25/75
# 2025-03-11 23:34:26,756 - INFO - Course processed in 1.74s - Progress: 25/75 (33.3%) - Elapsed: 0h 0m 46s - ETA: 0h 1m 32s
# 2025-03-11 23:34:26,757 - INFO - Processing course: 'BUS 431' - 26/75
# 2025-03-11 23:34:28,481 - INFO - Course processed in 1.72s - Progress: 26/75 (34.7%) - Elapsed: 0h 0m 48s - ETA: 0h 1m 30s
# 2025-03-11 23:34:28,483 - INFO - Processing course: 'BUS 441' - 27/75
# 2025-03-11 23:34:30,154 - INFO - Course processed in 1.67s - Progress: 27/75 (36.0%) - Elapsed: 0h 0m 49s - ETA: 0h 1m 28s
# 2025-03-11 23:34:30,156 - INFO - Processing course: 'BUS 493' - 28/75
# 2025-03-11 23:34:31,909 - INFO - Course processed in 1.75s - Progress: 28/75 (37.3%) - Elapsed: 0h 0m 51s - ETA: 0h 1m 26s
# 2025-03-11 23:34:31,911 - INFO - Processing course: 'INF 401' - 29/75
# 2025-03-11 23:34:33,667 - INFO - Course processed in 1.75s - Progress: 29/75 (38.7%) - Elapsed: 0h 0m 53s - ETA: 0h 1m 24s
# 2025-03-11 23:34:33,668 - INFO - Processing course: 'INF 412' - 30/75
# 2025-03-11 23:34:35,374 - INFO - Course processed in 1.70s - Progress: 30/75 (40.0%) - Elapsed: 0h 0m 55s - ETA: 0h 1m 22s
# 2025-03-11 23:34:35,377 - INFO - Processing course: 'BUS 442' - 31/75
# 2025-03-11 23:34:37,106 - INFO - Course processed in 1.73s - Progress: 31/75 (41.3%) - Elapsed: 0h 0m 56s - ETA: 0h 1m 20s
# 2025-03-11 23:34:37,108 - INFO - Processing course: 'BUS 211' - 32/75
# 2025-03-11 23:34:39,065 - INFO - Course processed in 1.95s - Progress: 32/75 (42.7%) - Elapsed: 0h 0m 58s - ETA: 0h 1m 19s
# 2025-03-11 23:34:39,067 - INFO - Processing course: 'INF 301' - 33/75
# 2025-03-11 23:34:40,797 - INFO - Course processed in 1.73s - Progress: 33/75 (44.0%) - Elapsed: 0h 1m 0s - ETA: 0h 1m 17s
# 2025-03-11 23:34:40,798 - INFO - Processing course: 'INF 302' - 34/75
# 2025-03-11 23:34:42,566 - INFO - Course processed in 1.77s - Progress: 34/75 (45.3%) - Elapsed: 0h 1m 2s - ETA: 0h 1m 15s
# 2025-03-11 23:34:42,568 - INFO - Processing course: 'BUS 352' - 35/75
# 2025-03-11 23:34:44,265 - INFO - Course processed in 1.70s - Progress: 35/75 (46.7%) - Elapsed: 0h 1m 4s - ETA: 0h 1m 13s
# 2025-03-11 23:34:44,267 - INFO - Processing course: 'BUS 431' - 36/75
# 2025-03-11 23:34:45,994 - INFO - Course processed in 1.73s - Progress: 36/75 (48.0%) - Elapsed: 0h 1m 5s - ETA: 0h 1m 11s
# 2025-03-11 23:34:45,995 - INFO - Processing course: 'INF 401' - 37/75
# 2025-03-11 23:34:47,730 - INFO - Course processed in 1.73s - Progress: 37/75 (49.3%) - Elapsed: 0h 1m 7s - ETA: 0h 1m 9s
# 2025-03-11 23:34:47,731 - INFO - Department 'International Finance' completed - 37 courses processed in 66.98s
# 2025-03-11 23:34:47,732 - INFO - Processing department: 'International Trade and Business' - URL: https://ects.bilgi.edu.tr/Department/Curriculum?catalog_departmentId=214500
# 2025-03-11 23:34:47,961 - INFO - Processing course: 'BUS 179' - 38/75
# 2025-03-11 23:34:49,752 - INFO - Course processed in 1.79s - Progress: 38/75 (50.7%) - Elapsed: 0h 1m 9s - ETA: 0h 1m 7s
# 2025-03-11 23:34:49,754 - INFO - Processing course: 'EC 101' - 39/75
# 2025-03-11 23:34:51,635 - INFO - Course processed in 1.88s - Progress: 39/75 (52.0%) - Elapsed: 0h 1m 11s - ETA: 0h 1m 5s
# 2025-03-11 23:34:51,636 - INFO - Processing course: 'BUS/E 179' - 40/75
# 2025-03-11 23:34:53,626 - INFO - Course processed in 1.99s - Progress: 40/75 (53.3%) - Elapsed: 0h 1m 13s - ETA: 0h 1m 4s
# 2025-03-11 23:34:53,627 - INFO - Processing course: 'MATH 175' - 41/75
# 2025-03-11 23:34:55,487 - INFO - Course processed in 1.86s - Progress: 41/75 (54.7%) - Elapsed: 0h 1m 15s - ETA: 0h 1m 2s
# 2025-03-11 23:34:55,488 - INFO - Processing course: 'TK 103' - 42/75
# 2025-03-11 23:34:57,391 - INFO - Course processed in 1.90s - Progress: 42/75 (56.0%) - Elapsed: 0h 1m 17s - ETA: 0h 1m 0s
# 2025-03-11 23:34:57,393 - INFO - Processing course: 'BUS 120' - 43/75
# 2025-03-11 23:34:59,105 - INFO - Course processed in 1.71s - Progress: 43/75 (57.3%) - Elapsed: 0h 1m 18s - ETA: 0h 0m 58s
# 2025-03-11 23:34:59,106 - INFO - Processing course: 'BUS 180' - 44/75
# 2025-03-11 23:35:01,081 - INFO - Course processed in 1.97s - Progress: 44/75 (58.7%) - Elapsed: 0h 1m 20s - ETA: 0h 0m 56s
# 2025-03-11 23:35:01,083 - INFO - Processing course: 'EC 102' - 45/75
# 2025-03-11 23:35:02,960 - INFO - Course processed in 1.88s - Progress: 45/75 (60.0%) - Elapsed: 0h 1m 22s - ETA: 0h 0m 55s
# 2025-03-11 23:35:02,962 - INFO - Processing course: 'BUS/E 180' - 46/75
# 2025-03-11 23:35:04,949 - INFO - Course processed in 1.98s - Progress: 46/75 (61.3%) - Elapsed: 0h 1m 24s - ETA: 0h 0m 53s
# 2025-03-11 23:35:04,950 - INFO - Processing course: 'MATH 176' - 47/75
# 2025-03-11 23:35:06,802 - INFO - Course processed in 1.85s - Progress: 47/75 (62.7%) - Elapsed: 0h 1m 26s - ETA: 0h 0m 51s
# 2025-03-11 23:35:06,803 - INFO - Processing course: 'TK 104' - 48/75
# 2025-03-11 23:35:08,716 - INFO - Course processed in 1.91s - Progress: 48/75 (64.0%) - Elapsed: 0h 1m 28s - ETA: 0h 0m 49s
# 2025-03-11 23:35:08,719 - INFO - Processing course: 'BUS 211' - 49/75
# 2025-03-11 23:35:10,531 - INFO - Course processed in 1.81s - Progress: 49/75 (65.3%) - Elapsed: 0h 1m 30s - ETA: 0h 0m 47s
# 2025-03-11 23:35:10,533 - INFO - Processing course: 'BUS 231' - 50/75
# 2025-03-11 23:35:12,298 - INFO - Course processed in 1.76s - Progress: 50/75 (66.7%) - Elapsed: 0h 1m 32s - ETA: 0h 0m 46s
# 2025-03-11 23:35:12,299 - INFO - Processing course: 'BUS 273' - 51/75
# 2025-03-11 23:35:14,085 - INFO - Course processed in 1.79s - Progress: 51/75 (68.0%) - Elapsed: 0h 1m 33s - ETA: 0h 0m 44s
# 2025-03-11 23:35:14,087 - INFO - Processing course: 'INT 202' - 52/75
# 2025-03-11 23:35:15,830 - INFO - Course processed in 1.74s - Progress: 52/75 (69.3%) - Elapsed: 0h 1m 35s - ETA: 0h 0m 42s
# 2025-03-11 23:35:15,832 - INFO - Processing course: 'BUS 212' - 53/75
# 2025-03-11 23:35:17,651 - INFO - Course processed in 1.82s - Progress: 53/75 (70.7%) - Elapsed: 0h 1m 37s - ETA: 0h 0m 40s
# 2025-03-11 23:35:17,653 - INFO - Processing course: 'BUS 274' - 54/75
# 2025-03-11 23:35:19,445 - INFO - Course processed in 1.79s - Progress: 54/75 (72.0%) - Elapsed: 0h 1m 39s - ETA: 0h 0m 38s
# 2025-03-11 23:35:19,446 - INFO - Processing course: 'BUS 311' - 55/75
# 2025-03-11 23:35:21,210 - INFO - Course processed in 1.76s - Progress: 55/75 (73.3%) - Elapsed: 0h 1m 40s - ETA: 0h 0m 36s
# 2025-03-11 23:35:21,213 - INFO - Processing course: 'BUS 331' - 56/75
# 2025-03-11 23:35:23,049 - INFO - Course processed in 1.83s - Progress: 56/75 (74.7%) - Elapsed: 0h 1m 42s - ETA: 0h 0m 34s
# 2025-03-11 23:35:23,053 - INFO - Processing course: 'BUS 341' - 57/75
# 2025-03-11 23:35:25,026 - INFO - Course processed in 1.97s - Progress: 57/75 (76.0%) - Elapsed: 0h 1m 44s - ETA: 0h 0m 33s
# 2025-03-11 23:35:25,028 - INFO - Processing course: 'BUS 350' - 58/75
# 2025-03-11 23:35:26,768 - INFO - Course processed in 1.74s - Progress: 58/75 (77.3%) - Elapsed: 0h 1m 46s - ETA: 0h 0m 31s
# 2025-03-11 23:35:26,770 - INFO - Processing course: 'HTR 111' - 59/75
# 2025-03-11 23:35:28,747 - INFO - Course processed in 1.97s - Progress: 59/75 (78.7%) - Elapsed: 0h 1m 48s - ETA: 0h 0m 29s
# 2025-03-11 23:35:28,748 - INFO - Processing course: 'INT 326' - 60/75
# 2025-03-11 23:35:30,501 - INFO - Course processed in 1.75s - Progress: 60/75 (80.0%) - Elapsed: 0h 1m 50s - ETA: 0h 0m 27s
# 2025-03-11 23:35:30,504 - INFO - Processing course: 'BUS 338' - 61/75
# 2025-03-11 23:35:32,287 - INFO - Course processed in 1.78s - Progress: 61/75 (81.3%) - Elapsed: 0h 1m 52s - ETA: 0h 0m 25s
# 2025-03-11 23:35:32,289 - INFO - Processing course: 'LAW 429' - 62/75
# 2025-03-11 23:35:34,031 - INFO - Course processed in 1.74s - Progress: 62/75 (82.7%) - Elapsed: 0h 1m 53s - ETA: 0h 0m 23s
# 2025-03-11 23:35:34,034 - INFO - Processing course: 'HTR 112' - 63/75
# 2025-03-11 23:35:35,877 - INFO - Course processed in 1.84s - Progress: 63/75 (84.0%) - Elapsed: 0h 1m 55s - ETA: 0h 0m 22s
# 2025-03-11 23:35:35,880 - INFO - Processing course: 'INT 427' - 64/75
# 2025-03-11 23:35:37,611 - INFO - Course processed in 1.73s - Progress: 64/75 (85.3%) - Elapsed: 0h 1m 57s - ETA: 0h 0m 20s
# 2025-03-11 23:35:37,612 - INFO - Processing course: 'INT 437' - 65/75
# 2025-03-11 23:35:39,266 - INFO - Course processed in 1.65s - Progress: 65/75 (86.7%) - Elapsed: 0h 1m 59s - ETA: 0h 0m 18s
# 2025-03-11 23:35:39,269 - INFO - Processing course: 'BUS 471' - 66/75
# 2025-03-11 23:35:41,068 - INFO - Course processed in 1.80s - Progress: 66/75 (88.0%) - Elapsed: 0h 2m 0s - ETA: 0h 0m 16s
# 2025-03-11 23:35:41,071 - INFO - Processing course: 'BUS 422' - 67/75
# 2025-03-11 23:35:42,822 - INFO - Course processed in 1.75s - Progress: 67/75 (89.3%) - Elapsed: 0h 2m 2s - ETA: 0h 0m 14s
# 2025-03-11 23:35:42,824 - INFO - Processing course: 'INF 401' - 68/75
# 2025-03-11 23:35:44,609 - INFO - Course processed in 1.78s - Progress: 68/75 (90.7%) - Elapsed: 0h 2m 4s - ETA: 0h 0m 12s
# 2025-03-11 23:35:44,613 - INFO - Processing course: 'BUS 211' - 69/75
# 2025-03-11 23:35:46,491 - INFO - Course processed in 1.88s - Progress: 69/75 (92.0%) - Elapsed: 0h 2m 6s - ETA: 0h 0m 10s
# 2025-03-11 23:35:46,494 - INFO - Processing course: 'EC 102' - 70/75
# 2025-03-11 23:35:48,391 - INFO - Course processed in 1.90s - Progress: 70/75 (93.3%) - Elapsed: 0h 2m 8s - ETA: 0h 0m 9s
# 2025-03-11 23:35:48,392 - INFO - Processing course: 'BUS 311' - 71/75
# 2025-03-11 23:35:50,121 - INFO - Course processed in 1.73s - Progress: 71/75 (94.7%) - Elapsed: 0h 2m 9s - ETA: 0h 0m 7s
# 2025-03-11 23:35:50,122 - INFO - Processing course: 'INT 202' - 72/75
# 2025-03-11 23:35:51,850 - INFO - Course processed in 1.73s - Progress: 72/75 (96.0%) - Elapsed: 0h 2m 11s - ETA: 0h 0m 5s
# 2025-03-11 23:35:51,851 - INFO - Processing course: 'INT 326' - 73/75
# 2025-03-11 23:35:53,696 - INFO - Course processed in 1.84s - Progress: 73/75 (97.3%) - Elapsed: 0h 2m 13s - ETA: 0h 0m 3s
# 2025-03-11 23:35:53,697 - INFO - Processing course: 'BUS 331' - 74/75
# 2025-03-11 23:35:55,452 - INFO - Course processed in 1.75s - Progress: 74/75 (98.7%) - Elapsed: 0h 2m 15s - ETA: 0h 0m 1s
# 2025-03-11 23:35:55,453 - INFO - Processing course: 'LAW 429' - 75/75
# 2025-03-11 23:35:57,191 - INFO - Course processed in 1.74s - Progress: 75/75 (100.0%) - Elapsed: 0h 2m 16s - ETA: 0h 0m 0s
# 2025-03-11 23:35:57,193 - INFO - Department 'International Trade and Business' completed - 38 courses processed in 69.46s
# 2025-03-11 23:35:57,196 - INFO - Done! All data saved to 'linkler_v2_results.json'
# 2025-03-11 23:35:57,199 - INFO - Scraping completed in 0h 2m 16s
# 2025-03-11 23:35:57,202 - INFO - Processed 75 courses from 2 departments
